# %%
df = spark.read.csv(
    "/Volumes/teste_koin/koin_origem/koin_origem/BRA - Cientista de dados - Customers .csv",
    header=True,
    inferSchema=True,
    sep=",",
    encoding="UTF-8"
)

df.write \
  .format("delta") \
  .mode("overwrite") \
  .option("overwriteSchema", "true") \
  .saveAsTable("teste_koin.default.bronze_customers")
